# %%
import pandas as pd

# %%
df = pd.read_csv("./bricodepot_scraper/products.csv")
df_c = pd.read_csv("./bricodepot_scraper/categories.csv")

# %%
df
# Out:
#                 sku                                              title  \
# 0     3663602576402  Sacs à gravats robustes 50 l - Haut. 82cm Larg...
# 1     3232637109055  Cornière fer laminé à chaud - L. 2,5 m, l. 2,5...
# 2     3663602565260               Sacs à gravats ultra-résistants 50 L
# 3     3183942930509  Huile de lin entretien, protection bois, carre...
# 4     5059340086729     Balais à main en bois Long. 285 mm Larg. 40 mm
# ...             ...                                                ...
# 3826  3663602942863  Poteau galva gris foncé "Neva" - H. 2,40 m Sec...
# 3827  3663602943181  Poteau pin teinté marron autoclave classe 4 "Z...
# 3828  3663602433255  Poteau bois vert - H. 2,40 m section 9 x 9 cm ...
# 3829  3663602943242  Support pour poteau bois à planter 70 mm x 70 ...
# 3830  3663602731542  Piquet raboté pin autoclave classe 4 - L. 2,0 ...
#
#                                                     url price  \
# ...

# %%
df['sub_subcategory'].value_counts()
# Out:
# sub_subcategory
# Portails à petit prix                147
# Produit entretien piscine            132
# Poteaux clôture                      128
# Grillage souple                      115
# Tronçonneuse                         105
# Eclairage portail, porte d'entrée     86
# Clôture bois                          80
# Salon de jardin                       75
# Plaquette de parement extérieure      75
# Eclairage terrasse                    75
# Pergola                               60
# Portillons                            59
# Eclairage allée et escaliers          58
# Piliers de portail                    56
# Store banne                           54
# Accessoires de barbecue               51
# Barbecue                              48
# Grillage rigide                       37
# Clôture aluminium                     34
# Brise vue jardin                      31
# Scie à bois                           27
# Clôture pvc                           26
# ...

# %%
df['sub_subcategory'].value_counts()
# Out:
# sub_subcategory
# Portails à petit prix                147
# Produit entretien piscine            132
# Poteaux clôture                      128
# Grillage souple                      115
# Tronçonneuse                         105
# Eclairage portail, porte d'entrée     86
# Clôture bois                          80
# Salon de jardin                       75
# Plaquette de parement extérieure      75
# Eclairage terrasse                    75
# Pergola                               60
# Portillons                            59
# Eclairage allée et escaliers          58
# Piliers de portail                    56
# Store banne                           54
# Accessoires de barbecue               51
# Barbecue                              48
# Grillage rigide                       37
# Clôture aluminium                     34
# Brise vue jardin                      31
# Scie à bois                           27
# Clôture pvc                           26
# ...

# %%
print(df['sub_subcategory'].nunique())
print(df['subcategory'].nunique())
print(df['category'].nunique())
# Out:
# 48
# 56
# 13

# %%
print(df_c['sub_subcategory'].nunique())
print(df_c['subcategory'].nunique())
print(df_c['category'].nunique())
# Out:
# 739
# 131
# 14
